# %%
from hehe import *
import pymongo

client = pymongo.MongoClient('mongodb+srv://dristiroy:gpH8AhvZ8NwnJDHo@dristicluster.86w9fpu.mongodb.net/')
print(client.list_database_names())
db = client['users']
dcOne = db['public']
dcTwo = db['private']
dcThree = db['coords']

dcOne.insert_one(getPublicUser('Dristi','Roy','driste',16, 'so lonely lol','branham computer science student :)', 'dristiroy@gmail.com',newId()))
# Out:
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# File c:\Users\stidr\AppData\Local\Programs\Python\Python39\lib\site-packages\dns\query.py:513, in _udp_recv(sock, max_size, expiration)
#     512 try:
# --> 513     return sock.recvfrom(max_size)
#     514 except BlockingIOError:
#
# BlockingIOError: [WinError 10035] A non-blocking socket operation could not be completed immediately
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from hehe import *
#       2 import pymongo
# ----> 4 client = pymongo.MongoClient('mongodb+srv://dristiroy:gpH8AhvZ8NwnJDHo@dristicluster.86w9fpu.mongodb.net/')
#       5 print(client.list_database_names())
#       6 db = client['users']
#
# ...
